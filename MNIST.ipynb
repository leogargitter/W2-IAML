# %% [markdown]
# # Work 02: Convolutional neura networks (CNNs)
# # Leonardo Gargitter GRR20172145
#
# ## Part 01: Theoretical
#
# ### 1. What is deep learning?
#
# ### 2. Why do we prefer CNNs over shallow artificial neural networks for image data?
#
#
#
# ### 3. Explain the role of the convolution layer in a CNN design.
#
# Convolutional neural networks are neural networks that use convolution in place of general matrix multiplication in at least one of its layers. Convolution adds the possibility to have sparse interactions, parameter sharing and equivariant representations.
#
# ### 4. What is the role of the fully connected (FC) layer in CNN?
#
# ### 5. Why do we use a pooling layer in a CNN?
#
# ### 6. Explain the characteristics of the following pooling approaches: max pooling, average pooling, and sum pooling.
#
# Max pooling:

# %% [markdown]
# ## Part 02: Practical
#
# ### 1. Test 5 setups for the CNNs with focus in the accuracy improve values (during training and test phases) for 20 (or more) learning epochs.
#
# ### 2. What was the best setup in terms of performance metrics (accuracy or MSE, Mean Squared Error) to the evaluated CNNs the MNIST and MNIST-like fashion product database?

# %% [markdown]
# # Código que vi no video do indiano
# https://www.youtube.com/watch?v=PiF0l6xif-k

# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

rows, cols = 28,28

x_train = x_train[0:3000]
y_train = y_train[0:3000]

x_test = x_test[0:500]
y_test = y_test[0:500]

x_train = x_train.reshape(x_train.shape[0], rows, cols, 1)
x_test = x_test.reshape(x_test.shape[0], rows, cols, 1)

input_shape = (rows, cols, 1)

#normalizar os valores dos pixels das imagens
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %%
#Lenet using max pooling
lenet_max_pooling = tf.keras.Sequential()

#Convolução 1
lenet_max_pooling.add(tf.keras.layers.Conv2D(filters=6, kernel_size=(5, 5), strides=(1, 1), activation='relu', input_shape=input_shape))
#Avarage pooling 1
lenet_max_pooling.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=(2, 2)))
#Convolução 2
lenet_max_pooling.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
#Avarage pooling 2
lenet_max_pooling.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=(2, 2)))
#flatten (converter os arrays bidimensionais para um vetor)
lenet_max_pooling.add(tf.keras.layers.Flatten())
#dense (fully connected)
lenet_max_pooling.add(tf.keras.layers.Dense(units=120, activation='relu'))
#flatten
lenet_max_pooling.add(tf.keras.layers.Flatten())
#dense (fully connected)
lenet_max_pooling.add(tf.keras.layers.Dense(units=84, activation='relu'))
#output
lenet_max_pooling.add(tf.keras.layers.Dense(units=10, activation='softmax'))
#compilação do modelo
lenet_max_pooling.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy', 'mse'])

# %%
#Lenet using avarage pooling
lenet_avg_pooling = tf.keras.Sequential()

#Convolução 1
lenet_avg_pooling.add(tf.keras.layers.Conv2D(filters=6, kernel_size=(5, 5), strides=(1, 1), activation='relu', input_shape=input_shape))
#Avarage pooling 1
lenet_avg_pooling.add(tf.keras.layers.AvgPool2D(pool_size=(2, 2), strides=(2, 2)))
#Convolução 2
lenet_avg_pooling.add(tf.keras.layers.Conv2D(filters=16, kernel_size=(5, 5), strides=(1, 1), activation='relu'))
#Avarage pooling 2
lenet_avg_pooling.add(tf.keras.layers.AvgPool2D(pool_size=(2, 2), strides=(2, 2)))
#flatten (converter os arrays bidimensionais para um vetor)
lenet_avg_pooling.add(tf.keras.layers.Flatten())
#dense (fully connected)
lenet_avg_pooling.add(tf.keras.layers.Dense(units=120, activation='relu'))
#flatten
lenet_avg_pooling.add(tf.keras.layers.Flatten())
#dense (fully connected)
lenet_avg_pooling.add(tf.keras.layers.Dense(units=84, activation='relu'))
#output
lenet_avg_pooling.add(tf.keras.layers.Dense(units=10, activation='softmax'))
#compilação do modelo
lenet_avg_pooling.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy', 'mse'])

# %%
lenet_max_pooling.fit(x_train, y_train, epochs=20)
print('LeNet Max Pooling result:')
lenet_max_pooling.evaluate(x_test, y_test)
# Out:
# Epoch 1/20
# 94/94 [==============================] - 3s 14ms/step - loss: 1.3361 - accuracy: 0.5680 - mse: 0.0566
# Epoch 2/20
# 94/94 [==============================] - 1s 14ms/step - loss: 0.4318 - accuracy: 0.8723 - mse: 0.0196
# Epoch 3/20
# 94/94 [==============================] - 1s 14ms/step - loss: 0.2674 - accuracy: 0.9207 - mse: 0.0120
# Epoch 4/20
# 94/94 [==============================] - 1s 16ms/step - loss: 0.2059 - accuracy: 0.9390 - mse: 0.0093
# Epoch 5/20
# 94/94 [==============================] - 1s 15ms/step - loss: 0.1582 - accuracy: 0.9557 - mse: 0.0072
# Epoch 6/20
# 94/94 [==============================] - 2s 18ms/step - loss: 0.1189 - accuracy: 0.9643 - mse: 0.0054
# Epoch 7/20
# 94/94 [==============================] - 2s 18ms/step - loss: 0.0976 - accuracy: 0.9720 - mse: 0.0044
# Epoch 8/20
# 94/94 [==============================] - 1s 16ms/step - loss: 0.0829 - accuracy: 0.9753 - mse: 0.0039
# Epoch 9/20
# 94/94 [==============================] - 2s 25ms/step - loss: 0.0792 - accuracy: 0.9763 - mse: 0.0038
# Epoch 10/20
# 94/94 [==============================] - 2s 23ms/step - loss: 0.0601 - accuracy: 0.9800 - mse: 0.0029
# Epoch 11/20
# 94/94 [==============================] - 2s 25ms/step - loss: 0.0462 - accuracy: 0.9887 - mse: 0.0021
# Epoch 12/20
# 94/94 [==============================] - 3s 27ms/step - loss: 0.0371 - accuracy: 0.9887 - mse: 0.0019
# Epoch 13/20
# 94/94 [==============================] - 2s 24ms/step - loss: 0.0326 - accuracy: 0.9917 - mse: 0.0015
# Epoch 14/20
# 94/94 [==============================] - 2s 21ms/step - loss: 0.0258 - accuracy: 0.9930 - mse: 0.0011
# Epoch 15/20
# 94/94 [==============================] - 3s 27ms/step - loss: 0.0214 - accuracy: 0.9947 - mse: 9.8223e-04
# Epoch 16/20
# 94/94 [==============================] - 2s 21ms/step - loss: 0.0169 - accuracy: 0.9947 - mse: 7.6813e-04
# Epoch 17/20
# 94/94 [==============================] - 2s 19ms/step - loss: 0.0153 - accuracy: 0.9967 - mse: 6.4355e-04
# Epoch 18/20
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0379 - accuracy: 0.9870 - mse: 0.0019
# Epoch 19/20
# 94/94 [==============================] - 2s 16ms/step - loss: 0.0239 - accuracy: 0.9937 - mse: 0.0012
# Epoch 20/20
# 94/94 [==============================] - 2s 23ms/step - loss: 0.0124 - accuracy: 0.9970 - mse: 5.5445e-04
# LeNet Max Pooling result:
# 16/16 [==============================] - 0s 10ms/step - loss: 0.1644 - accuracy: 0.9580 - mse: 0.0067
# [0.16443146765232086, 0.9580000042915344, 0.006678375881165266]

# %%
lenet_avg_pooling.fit(x_train, y_train, epochs=20)
print('LeNet Avarage Pooling result:')
lenet_avg_pooling.evaluate(x_test, y_test)
# Out:
# Epoch 1/20
# 94/94 [==============================] - 2s 14ms/step - loss: 1.3262 - accuracy: 0.5957 - mse: 0.0569
# Epoch 2/20
# 94/94 [==============================] - 1s 13ms/step - loss: 0.5095 - accuracy: 0.8433 - mse: 0.0231
# Epoch 3/20
# 94/94 [==============================] - 1s 13ms/step - loss: 0.3364 - accuracy: 0.9020 - mse: 0.0148
# Epoch 4/20
# 94/94 [==============================] - 1s 12ms/step - loss: 0.2595 - accuracy: 0.9260 - mse: 0.0118
# Epoch 5/20
# 94/94 [==============================] - 1s 14ms/step - loss: 0.2033 - accuracy: 0.9417 - mse: 0.0092
# Epoch 6/20
# 94/94 [==============================] - 1s 13ms/step - loss: 0.1706 - accuracy: 0.9467 - mse: 0.0078
# Epoch 7/20
# 94/94 [==============================] - 1s 12ms/step - loss: 0.1413 - accuracy: 0.9603 - mse: 0.0062
# Epoch 8/20
# 94/94 [==============================] - 1s 12ms/step - loss: 0.1256 - accuracy: 0.9620 - mse: 0.0058
# Epoch 9/20
# 94/94 [==============================] - 1s 12ms/step - loss: 0.1138 - accuracy: 0.9700 - mse: 0.0051
# Epoch 10/20
# 94/94 [==============================] - 1s 15ms/step - loss: 0.0938 - accuracy: 0.9733 - mse: 0.0042
# Epoch 11/20
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0817 - accuracy: 0.9720 - mse: 0.0039
# Epoch 12/20
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0769 - accuracy: 0.9747 - mse: 0.0037
# Epoch 13/20
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0657 - accuracy: 0.9813 - mse: 0.0031
# Epoch 14/20
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0549 - accuracy: 0.9853 - mse: 0.0025
# Epoch 15/20
# 94/94 [==============================] - 1s 14ms/step - loss: 0.0422 - accuracy: 0.9890 - mse: 0.0019
# Epoch 16/20
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0359 - accuracy: 0.9873 - mse: 0.0017
# Epoch 17/20
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0339 - accuracy: 0.9923 - mse: 0.0015
# Epoch 18/20
# 94/94 [==============================] - 1s 13ms/step - loss: 0.0311 - accuracy: 0.9913 - mse: 0.0015
# Epoch 19/20
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0388 - accuracy: 0.9857 - mse: 0.0020
# Epoch 20/20
# 94/94 [==============================] - 1s 12ms/step - loss: 0.0271 - accuracy: 0.9920 - mse: 0.0013
# LeNet Avarage Pooling result:
# 16/16 [==============================] - 0s 7ms/step - loss: 0.1179 - accuracy: 0.9580 - mse: 0.0057
# [0.11793879419565201, 0.9580000042915344, 0.005748452618718147]

# %%
dnn = tf.keras.Sequential()
dnn.add(tf.keras.layers.Conv2D(20, (3, 3), activation='relu', input_shape=input_shape))
dnn.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=(2, 2)))
dnn.add(tf.keras.layers.Conv2D(800, (5, 5), activation='relu', input_shape=input_shape))
dnn.add(tf.keras.layers.MaxPool2D(pool_size=(3, 3), strides=(3, 3)))
dnn.add(tf.keras.layers.Flatten())
dnn.add(tf.keras.layers.Dense(150, activation='relu', kernel_initializer='he_uniform'))
dnn.add(tf.keras.layers.Dense(10, activation='softmax'))

dnn.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy', 'mse'])

# %%
dnn.fit(x_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 94/94 [==============================] - 15s 147ms/step - loss: 0.7736 - accuracy: 0.7563 - mse: 0.0330
# Epoch 2/20
# 94/94 [==============================] - 15s 158ms/step - loss: 0.1914 - accuracy: 0.9427 - mse: 0.0087
# Epoch 3/20
# 94/94 [==============================] - 13s 143ms/step - loss: 0.1089 - accuracy: 0.9713 - mse: 0.0047
# Epoch 4/20
# 94/94 [==============================] - 18s 195ms/step - loss: 0.0818 - accuracy: 0.9747 - mse: 0.0038
# Epoch 5/20
# 94/94 [==============================] - 15s 157ms/step - loss: 0.0502 - accuracy: 0.9853 - mse: 0.0023
# Epoch 6/20
# 94/94 [==============================] - 17s 178ms/step - loss: 0.0333 - accuracy: 0.9903 - mse: 0.0016
# Epoch 7/20
# 94/94 [==============================] - 19s 199ms/step - loss: 0.0247 - accuracy: 0.9930 - mse: 0.0012
# Epoch 8/20
# 94/94 [==============================] - 19s 200ms/step - loss: 0.0305 - accuracy: 0.9900 - mse: 0.0017
# Epoch 9/20
# 94/94 [==============================] - 16s 174ms/step - loss: 0.0192 - accuracy: 0.9943 - mse: 9.6981e-04
# Epoch 10/20
# 94/94 [==============================] - 19s 198ms/step - loss: 0.0086 - accuracy: 0.9980 - mse: 3.9406e-04
# Epoch 11/20
# 94/94 [==============================] - 20s 208ms/step - loss: 0.0056 - accuracy: 0.9983 - mse: 2.3466e-04
# Epoch 12/20
# 94/94 [==============================] - 19s 198ms/step - loss: 0.0041 - accuracy: 0.9990 - mse: 1.7675e-04
# Epoch 13/20
# 94/94 [==============================] - 17s 175ms/step - loss: 0.0031 - accuracy: 0.9993 - mse: 1.4867e-04
# Epoch 14/20
# 94/94 [==============================] - 20s 212ms/step - loss: 0.0226 - accuracy: 0.9930 - mse: 0.0011
# Epoch 15/20
# 94/94 [==============================] - 21s 227ms/step - loss: 0.0176 - accuracy: 0.9953 - mse: 8.1971e-04
# Epoch 16/20
# 94/94 [==============================] - 18s 194ms/step - loss: 0.0059 - accuracy: 0.9983 - mse: 2.5866e-04
# Epoch 17/20
# 94/94 [==============================] - 19s 201ms/step - loss: 0.0177 - accuracy: 0.9950 - mse: 8.4230e-04
# Epoch 18/20
# 94/94 [==============================] - 17s 186ms/step - loss: 0.0167 - accuracy: 0.9950 - mse: 7.7506e-04
# Epoch 19/20
# 94/94 [==============================] - 17s 177ms/step - loss: 0.0119 - accuracy: 0.9963 - mse: 5.8326e-04
# Epoch 20/20
# 94/94 [==============================] - 18s 191ms/step - loss: 0.0044 - accuracy: 0.9987 - mse: 2.3509e-04

# %%
dnn.evaluate(x_test, y_test)
# Out:
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1219 - accuracy: 0.9700 - mse: 0.0048
# [0.12190018594264984, 0.9700000286102295, 0.00476972246542573]
